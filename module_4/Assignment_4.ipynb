# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Conditional statements (20 pts)
# - Set **x** to 5 and **y** to 6.
# - Test if they are equal using relational operators.
# - Test if they are not equal using the relational operators.
# - Test which one is larger by using the less than and greater than relational operators.
# - Use a ternary operator to set a new variable **z** to 0 by testing if **x** is less than or equal to **y**; Otherwise assign the value of **y** to **z**.

# %%
# Write your code here

# %% [markdown]
# ### 2. While loops (20 pts)
# - Set **day** to 1 and **fullMoon** to 29.
# - Create a **while** loop that checks if **day** is less than **fullMoon**. Inside the loop, increase **day** by 1 and print out the value of **day**.
# - Outside the loop, print a message "Today is a full moon."

# %%
# Write your code here

# %% [markdown]
# ### 3. If statements (20 pts)
# -  Set a variable **oldestCrust** to 3.5e9, **oldestSeafloor** to 180e6, **ageEarth** to 4.5e9, and  **ageSolarSystem** to 4.5e9
# -  Create an if-else statement that compares the age of the crust with the age of the seafloor and prints out which is older
# - Create an if-else statement that compares the age of the Earth and the age of the solar system and prints out whether or not they formed at the same time

# %%
# Write your code here

# %% [markdown]
# ### 4. For loops (20 pts)
# - Create a list of integers using **range()** function starting from 0 to 20 at a step of 3
# - Write a **for** loop; inside the loop, write an **if** statement to print out all of the elements in your list that can be exactly divisible by 2.

# %%
# Write your code here

# %% [markdown]
# ### 5. Nested loops (20 pts)
# - Make a dictionary of volcanoes with volcano names as keys and most recent eruption years as values: "Mt St Helen's":1981, 'Pinatubo':1992, 'Krakatoa':2014, 'Anak Krakatoa': 2018, 'Yellowstone':-68000, 'Kilauea':2018"
# - Make a nested loop: step through the dictionary of volcanoes. If the last eruption was after 2000, print a message 'Recent activity at ' along with the volcano name, otherwise print 'No recent activity at ' followed by the volcano name.

# %%
# Write your code here

# %% [markdown]
# ### 6. List comprehension
#
# - Create a string variable as "We are learning Python Programming in Geosciences"
# - Convert the string into a list of individual words using the string method **.split()**
# - Use list comprehension to find the words with a length of at least 10.
# - Use list comprehension to find the words containing a substring 'ing'. Hint: use the **in** keyword.
# - Use list comprehension to find the words with a length of at least 10 **and** containing a substring 'ing'.
# - Use list comprehension to find the words with a length of at least 10 **or** containing a substring 'ing'.
# - Use list comprehension to find the words with a length of at least 10 and convert them to all capital letters. Hint: the **.upper()** method converts a string to all capital letters.

# %%
# Write your code here
