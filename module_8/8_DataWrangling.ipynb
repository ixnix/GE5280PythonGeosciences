# %% [markdown]
# # Module 8: Data Wrangling

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image

# %% [markdown]
# ## Introduction
# In this module, we build on your foundational Pandas skills and explore more advanced techniques for manipulating and combining datasets. You will learn how to filter and sort data efficiently in order to uncover insights from large DataFrames. We will also cover concatenating and merging operations to combine multiple datasets into a single, coherent structure. By the end, you will be able to perform more complex data wrangling tasks and prepare datasets for in-depth analysis.
#
# ## Learning Objectives
# - Apply advanced filtering and sorting techniques to Pandas DataFrames.
# - Combine datasets using concatenation and merging operations in Pandas.
#
# ## Reading
# - [Chapter 5](https://wesmckinney.com/book/pandas-basics)
# - [Chapter 8](https://wesmckinney.com/book/data-wrangling)

# %% [markdown]
# ## Locating and Editing Data
#
# Today we are going to learn about filtering pandas DataFrames. Pandas provides a powerful way to tease out useful information.
#
# We will be looking at data on Holocene Eruptions from the Smithsonian Holocene Volcano Database: http://volcano.si.edu/list_volcano_holocene.cfm. This link will download an xml file, which Excel can read, but for Pandas to work on it, we can convert it to a CSV file (UTF-8 encoding) from with excel.
#
# We will see how to filter these data to pull out interesting information on Holocene Eruptions. Let's read in this data and first look at its length. If you look in the file, you will see that the header is in the second line (not the first), so header=1 in the argument list, after the PATH to the file.

# %%
EruptionData = pd.read_csv('data/GVP_Volcano_List_Holocene.csv',header=1)
print('Number of Eruptions:',len(EruptionData))
EruptionData.head()
# Out:
# Number of Eruptions: 1424
#    Volcano Number               Volcano Name  Country Primary Volcano Type  \
# 0          210010  West Eifel Volcanic Field  Germany              Maar(s)
# 1          210020            Chaine des Puys   France         Lava dome(s)
# 2          210030        Olot Volcanic Field    Spain  Pyroclastic cone(s)
# 3          210040   Calatrava Volcanic Field    Spain  Pyroclastic cone(s)
# 4          211003                    Vulsini    Italy              Caldera
#
#    Activity Evidence Last Known Eruption                          Region  \
# 0     Eruption Dated            8300 BCE  Mediterranean and Western Asia
# 1     Eruption Dated            4040 BCE  Mediterranean and Western Asia
# 2  Evidence Credible             Unknown  Mediterranean and Western Asia
# 3     Eruption Dated            3600 BCE  Mediterranean and Western Asia
# 4  Eruption Observed             104 BCE  Mediterranean and Western Asia
#
#         Subregion  Latitude  Longitude  Elevation (m)  \
# 0  Western Europe    50.170       6.85            600
# 1  Western Europe    45.775       2.97           1464
# 2  Western Europe    42.170       2.53            893
# 3  Western Europe    38.870      -4.02           1117
# 4           Italy    42.600      11.93            800
#
#                  Dominant Rock Type  \
# 0                           Foidite
# 1             Basalt / Picro-Basalt
# 2  Trachybasalt / Tephrite Basanite
# 3             Basalt / Picro-Basalt
# 4           Trachyte / Trachydacite
#
#                                Tectonic Setting
# 0        Rift zone / Continental crust (>25 km)
# 1        Rift zone / Continental crust (>25 km)
# 2       Intraplate / Continental crust (>25 km)
# 3       Intraplate / Continental crust (>25 km)
# 4  Subduction zone / Continental crust (>25 km)

# %% [markdown]
# Wow, that's a lot of Eruptions! However, the DataFrame has a lot of information we really aren't interested in. For example, there are many eruptions in this data for which the evidence isn't strong ('Evidence Uncertain'). You can verify this, by printing out the **Series** "Activity Evidence".

# %%
EruptionData['Activity Evidence']
# Out:
# 0           Eruption Dated
# 1           Eruption Dated
# 2        Evidence Credible
# 3           Eruption Dated
# 4        Eruption Observed
#                ...
# 1419     Unrest / Holocene
# 1420     Eruption Observed
# 1421     Eruption Observed
# 1422     Evidence Credible
# 1423    Evidence Uncertain
# Name: Activity Evidence, Length: 1424, dtype: object

# %% [markdown]
# In the previous module, we learned how to filter a DataFrame by putting what we wanted in a conditional statement enclosed in square brackets. Remembering that the conditional for "equal to" is "==", we can retrieve all the rows that contain 'Eruption Observed' in the column 'Activity Evidence' like this:

# %%
#notice the conditional '==' which means 'equals to'
ObservedEruptions = EruptionData[EruptionData['Activity Evidence']=='Eruption Observed']
ObservedEruptions.head()
# Out:
#     Volcano Number   Volcano Name Country Primary Volcano Type  \
# 4           211003        Vulsini   Italy              Caldera
# 6           211010  Campi Flegrei   Italy              Caldera
# 7           211020       Vesuvius   Italy        Stratovolcano
# 8           211030         Ischia   Italy              Complex
# 10          211040      Stromboli   Italy        Stratovolcano
#
#     Activity Evidence Last Known Eruption                          Region  \
# 4   Eruption Observed             104 BCE  Mediterranean and Western Asia
# 6   Eruption Observed             1538 CE  Mediterranean and Western Asia
# 7   Eruption Observed             1944 CE  Mediterranean and Western Asia
# 8   Eruption Observed             1302 CE  Mediterranean and Western Asia
# 10  Eruption Observed             2020 CE  Mediterranean and Western Asia
#
#    Subregion  Latitude  Longitude  Elevation (m)  \
# 4      Italy    42.600     11.930            800
# 6      Italy    40.827     14.139            458
# 7      Italy    40.821     14.426           1281
# 8      Italy    40.730     13.897            789
# 10     Italy    38.789     15.213            924
#
#                           Dominant Rock Type  \
# 4                    Trachyte / Trachydacite
# 6                    Trachyte / Trachydacite
# 7         Phono-tephrite /  Tephri-phonolite
# 8                    Trachyte / Trachydacite
# 10  Trachyandesite / Basaltic Trachyandesite
#
#                                 Tectonic Setting
# 4   Subduction zone / Continental crust (>25 km)
# 6   Subduction zone / Continental crust (>25 km)
# 7   Subduction zone / Continental crust (>25 km)
# 8   Subduction zone / Continental crust (>25 km)
# 10  Subduction zone / Continental crust (>25 km)

# %% [markdown]
# **DataFrame.loc[]** allows for filtering of DataFrames by label(s) or a boolean array.
#
# Allowed inputs are:
# - A single label, e.g. 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
# - A list or array of labels, e.g. ['a', 'b', 'c'].
# - A slice object with labels, e.g. 'a':'f'.
# - A boolean array of the same length as the axis being sliced, e.g. [True, False, True].

# %%
EruptionData.loc[EruptionData['Activity Evidence']=='Eruption Observed'].head()
# Out:
#     Volcano Number   Volcano Name Country Primary Volcano Type  \
# 4           211003        Vulsini   Italy              Caldera
# 6           211010  Campi Flegrei   Italy              Caldera
# 7           211020       Vesuvius   Italy        Stratovolcano
# 8           211030         Ischia   Italy              Complex
# 10          211040      Stromboli   Italy        Stratovolcano
#
#     Activity Evidence Last Known Eruption                          Region  \
# 4   Eruption Observed             104 BCE  Mediterranean and Western Asia
# 6   Eruption Observed             1538 CE  Mediterranean and Western Asia
# 7   Eruption Observed             1944 CE  Mediterranean and Western Asia
# 8   Eruption Observed             1302 CE  Mediterranean and Western Asia
# 10  Eruption Observed             2020 CE  Mediterranean and Western Asia
#
#    Subregion  Latitude  Longitude  Elevation (m)  \
# 4      Italy    42.600     11.930            800
# 6      Italy    40.827     14.139            458
# 7      Italy    40.821     14.426           1281
# 8      Italy    40.730     13.897            789
# 10     Italy    38.789     15.213            924
#
#                           Dominant Rock Type  \
# 4                    Trachyte / Trachydacite
# 6                    Trachyte / Trachydacite
# 7         Phono-tephrite /  Tephri-phonolite
# 8                    Trachyte / Trachydacite
# 10  Trachyandesite / Basaltic Trachyandesite
#
#                                 Tectonic Setting
# 4   Subduction zone / Continental crust (>25 km)
# 6   Subduction zone / Continental crust (>25 km)
# 7   Subduction zone / Continental crust (>25 km)
# 8   Subduction zone / Continental crust (>25 km)
# 10  Subduction zone / Continental crust (>25 km)

# %% [markdown]
# This statement does exactly the same thing as the conditional. The syntax of a **.loc** statement might look trickier, but it will make your life easier as things get more complicated. It is computationally faster and has more tricks up its sleeve as we shall see soon.

# %% [markdown]
# Now let's look at some big eruptions we might be interested in. One of the most famous Volcanic eruptions is the 1980 Eruption of Mount St. Helens (Washington State). To find it, let's search for Holocene Eruptions of Mount St. Helens.

# %%
EruptionData.loc[EruptionData['Volcano Name']=='St. Helens']
# Out:
#      Volcano Number Volcano Name        Country Primary Volcano Type  \
# 937          321050   St. Helens  United States        Stratovolcano
#
#      Activity Evidence Last Known Eruption                  Region  \
# 937  Eruption Observed             2008 CE  Canada and Western USA
#
#             Subregion  Latitude  Longitude  Elevation (m) Dominant Rock Type  \
# 937  USA (Washington)      46.2    -122.18           2549             Dacite
#
#                                  Tectonic Setting
# 937  Subduction zone / Continental crust (>25 km)

# %% [markdown]
# As we can see, simple conditional statements like this enable us to filter large datasets for the small amount of information we're interested in.
#
# Although the above statement would work equally well without the **.loc** method, we can add some whistles and bells. The use of the **.loc** syntax allows us to search through a particular column (Series) by putting a comma after your conditional statement followed by another Series name.
#
# That is, **.loc** supports simultaneous row and column selection.
#
# Say we want the 'Last Known Eruption' of all stratovolcanoes. We could do this:

# %%
stratos = EruptionData.loc[EruptionData['Primary Volcano Type'].str.contains('Stratovolcano'),'Last Known Eruption']
stratos.head()
# Out:
# 7     1944 CE
# 10    2020 CE
# 11    Unknown
# 12    1230 CE
# 13    1890 CE
# Name: Last Known Eruption, dtype: object

# %% [markdown]
# Here we used the syntax **DataFrame.Series.str.contains( )**. This allows us to get not only the type "Stratovolcano", but also "Stratovolcano(es)" and anything that has "Stratovolcano" in it.
#
# It is worth pointing out another way to accomplish the same thing using the method **isin()**. You can create a list of things you want (or don't want), then test if the string is in the list. Here is how it would work for this example to select things in the list:

# %%
volcano_types = ['Stratovolcano','Stratovolcano(es)']
stratos = EruptionData[EruptionData['Primary Volcano Type'].isin(volcano_types)]
stratos.head()
# Out:
#     Volcano Number Volcano Name Country Primary Volcano Type  \
# 7           211020     Vesuvius   Italy        Stratovolcano
# 10          211040    Stromboli   Italy        Stratovolcano
# 11          211041      Panarea   Italy        Stratovolcano
# 12          211042       Lipari   Italy    Stratovolcano(es)
# 13          211050      Vulcano   Italy    Stratovolcano(es)
#
#      Activity Evidence Last Known Eruption                          Region  \
# 7    Eruption Observed             1944 CE  Mediterranean and Western Asia
# 10   Eruption Observed             2020 CE  Mediterranean and Western Asia
# 11  Evidence Uncertain             Unknown  Mediterranean and Western Asia
# 12      Eruption Dated             1230 CE  Mediterranean and Western Asia
# 13   Eruption Observed             1890 CE  Mediterranean and Western Asia
#
#    Subregion  Latitude  Longitude  Elevation (m)  \
# 7      Italy    40.821     14.426           1281
# 10     Italy    38.789     15.213            924
# 11     Italy    38.638     15.064            399
# 12     Italy    38.490     14.933            590
# 13     Italy    38.404     14.962            500
#
#                           Dominant Rock Type  \
# 7         Phono-tephrite /  Tephri-phonolite
# 10  Trachyandesite / Basaltic Trachyandesite
# 11              Andesite / Basaltic Andesite
# 12                                  Rhyolite
# 13          Trachybasalt / Tephrite Basanite
#
#                                 Tectonic Setting
# 7   Subduction zone / Continental crust (>25 km)
# 10  Subduction zone / Continental crust (>25 km)
# 11  Subduction zone / Continental crust (>25 km)
# 12  Subduction zone / Continental crust (>25 km)
# 13  Subduction zone / Continental crust (>25 km)

# %% [markdown]
# And here's how it works if you don't want things in the list:

# %%
volcano_types = ['Stratovolcano','Stratovolcano(es)']
not_stratos = EruptionData[EruptionData['Primary Volcano Type'].isin(volcano_types)==False]
not_stratos.head()
# Out:
#    Volcano Number               Volcano Name  Country Primary Volcano Type  \
# 0          210010  West Eifel Volcanic Field  Germany              Maar(s)
# 1          210020            Chaine des Puys   France         Lava dome(s)
# 2          210030        Olot Volcanic Field    Spain  Pyroclastic cone(s)
# 3          210040   Calatrava Volcanic Field    Spain  Pyroclastic cone(s)
# 4          211003                    Vulsini    Italy              Caldera
#
#    Activity Evidence Last Known Eruption                          Region  \
# 0     Eruption Dated            8300 BCE  Mediterranean and Western Asia
# 1     Eruption Dated            4040 BCE  Mediterranean and Western Asia
# 2  Evidence Credible             Unknown  Mediterranean and Western Asia
# 3     Eruption Dated            3600 BCE  Mediterranean and Western Asia
# 4  Eruption Observed             104 BCE  Mediterranean and Western Asia
#
#         Subregion  Latitude  Longitude  Elevation (m)  \
# 0  Western Europe    50.170       6.85            600
# 1  Western Europe    45.775       2.97           1464
# 2  Western Europe    42.170       2.53            893
# 3  Western Europe    38.870      -4.02           1117
# 4           Italy    42.600      11.93            800
#
#                  Dominant Rock Type  \
# 0                           Foidite
# 1             Basalt / Picro-Basalt
# 2  Trachybasalt / Tephrite Basanite
# 3             Basalt / Picro-Basalt
# 4           Trachyte / Trachydacite
#
#                                Tectonic Setting
# 0        Rift zone / Continental crust (>25 km)
# 1        Rift zone / Continental crust (>25 km)
# 2       Intraplate / Continental crust (>25 km)
# 3       Intraplate / Continental crust (>25 km)
# 4  Subduction zone / Continental crust (>25 km)

# %% [markdown]
# Now we can do stuff to this filtered DataFrame **stratos**. The **.loc** syntax also allows you to take a slice through the columns list to select a specific range of column headers:

# %%
ColumnSlice = EruptionData.loc[EruptionData['Primary Volcano Type'].str.contains('Stratovolcano'), 'Volcano Name':'Last Known Eruption']
ColumnSlice.head()
# Out:
#    Volcano Name Country Primary Volcano Type   Activity Evidence  \
# 7      Vesuvius   Italy        Stratovolcano   Eruption Observed
# 10    Stromboli   Italy        Stratovolcano   Eruption Observed
# 11      Panarea   Italy        Stratovolcano  Evidence Uncertain
# 12       Lipari   Italy    Stratovolcano(es)      Eruption Dated
# 13      Vulcano   Italy    Stratovolcano(es)   Eruption Observed
#
#    Last Known Eruption
# 7              1944 CE
# 10             2020 CE
# 11             Unknown
# 12             1230 CE
# 13             1890 CE

# %% [markdown]
# Something else **.loc** can do is to change the values _inplace_ in DataFrames easily. Let's say we found a historical document that told us that the Unknown last eruption at Panarea was in 5000 BCE. We want to update the information in the **DataFrame** and can do it this way:

# %%
print('Before modifying:\n',EruptionData.loc[EruptionData['Volcano Name']=='Panarea','Last Known Eruption'])

EruptionData.loc[EruptionData['Volcano Name']=='Panarea','Last Known Eruption'] = '5000 BCE'

# and let's take a look: 
print('After modifying:\n',EruptionData.loc[EruptionData['Volcano Name']=='Panarea','Last Known Eruption'])
# Out:
# Before modifying:
#  11    Unknown
# Name: Last Known Eruption, dtype: object
# After modifying:
#  11    5000 BCE
# Name: Last Known Eruption, dtype: object

# %% [markdown]
# As we can see, the syntax for this can get complicated quickly, but we can retrieve and modify lots of data using a few lines of code.

# %% [markdown]
# ## Adding new columns
#
# How can we add a new column based on existing data in the dataframe? Say, we would like to create a new column _NS_ in the data frame based on the volcano latitude:

# %%
EruptionData['NS'] = np.nan
EruptionData.loc[ EruptionData.Latitude>0, 'NS'] = 'N'
EruptionData.loc[ EruptionData.Latitude<0, 'NS'] = 'S'
# Out:
# /var/folders/d6/gwgxc4k54kn3257svv59qtgh0000gp/T/ipykernel_7652/1933396553.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   EruptionData.loc[ EruptionData.Latitude>0, 'NS'] = 'N'

# %% [markdown]
# Or, we can use **lambda function** to add the new column in just one line of code:

# %%
EruptionData['NS'] = EruptionData['Latitude'].map(lambda x: 'N' if x>0 else 'S')
EruptionData.head(5)
# Out:
#    Volcano Number               Volcano Name  Country Primary Volcano Type  \
# 0          210010  West Eifel Volcanic Field  Germany              Maar(s)
# 1          210020            Chaine des Puys   France         Lava dome(s)
# 2          210030        Olot Volcanic Field    Spain  Pyroclastic cone(s)
# 3          210040   Calatrava Volcanic Field    Spain  Pyroclastic cone(s)
# 4          211003                    Vulsini    Italy              Caldera
#
#    Activity Evidence Last Known Eruption                          Region  \
# 0     Eruption Dated            8300 BCE  Mediterranean and Western Asia
# 1     Eruption Dated            4040 BCE  Mediterranean and Western Asia
# 2  Evidence Credible             Unknown  Mediterranean and Western Asia
# 3     Eruption Dated            3600 BCE  Mediterranean and Western Asia
# 4  Eruption Observed             104 BCE  Mediterranean and Western Asia
#
#         Subregion  Latitude  Longitude  Elevation (m)  \
# 0  Western Europe    50.170       6.85            600
# 1  Western Europe    45.775       2.97           1464
# 2  Western Europe    42.170       2.53            893
# 3  Western Europe    38.870      -4.02           1117
# 4           Italy    42.600      11.93            800
#
#                  Dominant Rock Type  \
# 0                           Foidite
# 1             Basalt / Picro-Basalt
# 2  Trachybasalt / Tephrite Basanite
# 3             Basalt / Picro-Basalt
# 4           Trachyte / Trachydacite
#
#                                Tectonic Setting NS
# 0        Rift zone / Continental crust (>25 km)  N
# 1        Rift zone / Continental crust (>25 km)  N
# 2       Intraplate / Continental crust (>25 km)  N
# 3       Intraplate / Continental crust (>25 km)  N
# 4  Subduction zone / Continental crust (>25 km)  N

# %% [markdown]
# To verify the successful creation of the new column,

# %%
EruptionData.columns
# Out:
# Index(['Volcano Number', 'Volcano Name', 'Country', 'Primary Volcano Type',
#        'Activity Evidence', 'Last Known Eruption', 'Region', 'Subregion',
#        'Latitude', 'Longitude', 'Elevation (m)', 'Dominant Rock Type',
#        'Tectonic Setting', 'NS'],
#       dtype='object')

# %% [markdown]
# Filter the data frame based on the Elevation (m) and NS columns:

# %%
EruptionData[(EruptionData['Elevation (m)'] > 3000) & (EruptionData['NS'] == 'N')]
# Out:
#       Volcano Number   Volcano Name  Country Primary Volcano Type  \
# 14            211060           Etna    Italy    Stratovolcano(es)
# 25            213002     Hasan Dagi   Turkey        Stratovolcano
# 28            213010   Erciyes Dagi   Turkey        Stratovolcano
# 31            213030  Tenduruk Dagi   Turkey               Shield
# 32            213040         Ararat   Turkey        Stratovolcano
# ...              ...            ...      ...                  ...
# 1141          352004       Imbabura  Ecuador             Compound
# 1142          352005        Mojanda  Ecuador    Stratovolcano(es)
# 1143          352006        Cayambe  Ecuador             Compound
# 1145          352011      Pululahua  Ecuador              Caldera
# 1379          383030       Tenerife    Spain        Stratovolcano
#
#        Activity Evidence Last Known Eruption                          Region  \
# 14     Eruption Observed             2020 CE  Mediterranean and Western Asia
# 25     Evidence Credible             Unknown  Mediterranean and Western Asia
# 28        Eruption Dated            6880 BCE  Mediterranean and Western Asia
# 31     Eruption Observed             1855 CE  Mediterranean and Western Asia
# 32     Eruption Observed             1840 CE  Mediterranean and Western Asia
# ...                  ...                 ...                             ...
# 1141      Eruption Dated            5550 BCE                   South America
# 1142  Evidence Uncertain             Unknown                   South America
# 1143   Eruption Observed             1786 CE                   South America
# 1145      Eruption Dated              290 CE                   South America
# 1379   Eruption Observed             1909 CE                  Atlantic Ocean
#
#            Subregion  Latitude  Longitude  Elevation (m)  \
# 14             Italy    37.748     14.999           3295
# 25            Turkey    38.130     34.170           3253
# 28            Turkey    38.531     35.447           3864
# 31            Turkey    39.356     43.874           3514
# 32            Turkey    39.700     44.300           5165
# ...              ...       ...        ...            ...
# 1141         Ecuador     0.258    -78.183           4609
# 1142         Ecuador     0.130    -78.270           4263
# 1143         Ecuador     0.029    -77.986           5790
# 1145         Ecuador     0.038    -78.463           3356
# 1379  Canary Islands    28.271    -16.641           3715
#
#                     Dominant Rock Type  \
# 14    Trachybasalt / Tephrite Basanite
# 25                              Dacite
# 28                              Dacite
# 31               Basalt / Picro-Basalt
# 32        Andesite / Basaltic Andesite
# ...                                ...
# 1141      Andesite / Basaltic Andesite
# 1142      Andesite / Basaltic Andesite
# 1143      Andesite / Basaltic Andesite
# 1145                            Dacite
# 1379                         Phonolite
#
#                                   Tectonic Setting NS
# 14    Subduction zone / Continental crust (>25 km)  N
# 25         Intraplate / Continental crust (>25 km)  N
# 28         Intraplate / Continental crust (>25 km)  N
# 31         Intraplate / Continental crust (>25 km)  N
# 32         Intraplate / Continental crust (>25 km)  N
# ...                                            ... ..
# 1141  Subduction zone / Continental crust (>25 km)  N
# 1142  Subduction zone / Continental crust (>25 km)  N
# 1143  Subduction zone / Continental crust (>25 km)  N
# 1145  Subduction zone / Continental crust (>25 km)  N
# 1379          Intraplate / Oceanic crust (< 15 km)  N
#
# [109 rows x 14 columns]

# %% [markdown]
# ## Sorting and Indexing
#
# What if we wanted to sort our dataset so the most northerly eruptions come out on top? Pandas DataFrames have a method for this called **sort_values**.
#
# Normally, this will sort from lowest to highest (an "ascending" sort), but we can use the argument **ascending=False** to tell it to sort from highest to lowest.

# %%
# First read in our DataFrame again:
EruptionData = pd.read_csv('data/GVP_Volcano_List_Holocene.csv',header=1)
NorthernToSouthern = EruptionData.sort_values(by='Latitude',ascending=False)
NorthernToSouthern.head()
# Out:
#       Volcano Number               Volcano Name            Country  \
# 1361          377020  East Gakkel Ridge at 85°E  Undersea Features
# 1360          376010                  Jan Mayen             Norway
# 1359          375010           Kolbeinsey Ridge            Iceland
# 1355          373100      Tjornes Fracture Zone            Iceland
# 1354          373090              Theistareykir            Iceland
#
#      Primary Volcano Type  Activity Evidence Last Known Eruption  \
# 1361            Submarine  Evidence Credible             1999 CE
# 1360        Stratovolcano  Eruption Observed             1985 CE
# 1359            Submarine  Eruption Observed             1755 CE
# 1355            Submarine  Eruption Observed             1868 CE
# 1354               Shield     Eruption Dated             900 BCE
#
#                         Region                   Subregion  Latitude  \
# 1361  Iceland and Arctic Ocean                Arctic Ocean    85.608
# 1360  Iceland and Arctic Ocean  Atlantic Ocean (Jan Mayen)    71.082
# 1359  Iceland and Arctic Ocean            North of Iceland    66.670
# 1355  Iceland and Arctic Ocean      Iceland (northeastern)    66.309
# 1354  Iceland and Arctic Ocean      Iceland (northeastern)    65.833
#
#       Longitude  Elevation (m)     Dominant Rock Type  \
# 1361     85.250          -3800      No Data (checked)
# 1360     -8.155           2197  Basalt / Picro-Basalt
# 1359    -18.500              5  Basalt / Picro-Basalt
# 1355    -17.118            -75  Basalt / Picro-Basalt
# 1354    -17.166            540  Basalt / Picro-Basalt
#
#                          Tectonic Setting
# 1361  Rift zone / Oceanic crust (< 15 km)
# 1360  Rift zone / Oceanic crust (< 15 km)
# 1359  Rift zone / Oceanic crust (< 15 km)
# 1355  Rift zone / Oceanic crust (< 15 km)
# 1354  Rift zone / Oceanic crust (< 15 km)

# %% [markdown]
# Looks like the most northerly eruptions during the Holocene were at the East Gakkel Ridge and that the most northerly above sea-level eruption was on Jan Mayen in 1985.
#
# Now let's try to get the first 10 rows in this DataFrame. We can do this using **.loc**, right?

# %%
NorthernToSouthern.loc[0:10]
# Out:
#      Volcano Number               Volcano Name        Country  \
# 0            210010  West Eifel Volcanic Field        Germany
# 692          290350            Karpinsky Group         Russia
# 932          320811      Cayley Volcanic Field         Canada
# 930          320190             Garibaldi Lake         Canada
# 931          320200                  Garibaldi         Canada
# ..              ...                        ...            ...
# 957          323100                 Clear Lake  United States
# 971          327050          Black Rock Desert  United States
# 572          283210               Kurikomayama          Japan
# 3            210040   Calatrava Volcanic Field          Spain
# 10           211040                  Stromboli          Italy
#
#     Primary Volcano Type  Activity Evidence Last Known Eruption  \
# 0                Maar(s)     Eruption Dated            8300 BCE
# 692              Cone(s)  Eruption Observed             1952 CE
# 932       Volcanic field  Evidence Credible             Unknown
# 930       Volcanic field  Evidence Credible             Unknown
# 931        Stratovolcano     Eruption Dated            8060 BCE
# ..                   ...                ...                 ...
# 957       Volcanic field  Evidence Credible             Unknown
# 971       Volcanic field     Eruption Dated             1290 CE
# 572        Stratovolcano  Eruption Observed             1950 CE
# 3    Pyroclastic cone(s)     Eruption Dated            3600 BCE
# 10         Stratovolcano  Eruption Observed             2020 CE
#
#                              Region         Subregion  Latitude  Longitude  \
# 0    Mediterranean and Western Asia    Western Europe    50.170      6.850
# 692                   Kuril Islands     Kuril Islands    50.148    155.373
# 932          Canada and Western USA            Canada    50.120   -123.280
# 930          Canada and Western USA            Canada    49.933   -123.000
# 931          Canada and Western USA            Canada    49.850   -123.000
# ..                              ...               ...       ...        ...
# 957          Canada and Western USA  USA (California)    38.970   -122.770
# 971          Canada and Western USA        USA (Utah)    38.970   -112.500
# 572         Japan, Taiwan, Marianas            Honshu    38.961    140.788
# 3    Mediterranean and Western Asia    Western Europe    38.870     -4.020
# 10   Mediterranean and Western Asia             Italy    38.789     15.213
#
#      Elevation (m)                        Dominant Rock Type  \
# 0              600                                   Foidite
# 692           1326              Andesite / Basaltic Andesite
# 932           2375              Andesite / Basaltic Andesite
# 930           2316              Andesite / Basaltic Andesite
# 931           2678                                    Dacite
# ..             ...                                       ...
# 957           1439                                    Dacite
# 971           1800                     Basalt / Picro-Basalt
# 572           1627              Andesite / Basaltic Andesite
# 3             1117                     Basalt / Picro-Basalt
# 10             924  Trachyandesite / Basaltic Trachyandesite
#
#                                  Tectonic Setting
# 0          Rift zone / Continental crust (>25 km)
# 692  Subduction zone / Continental crust (>25 km)
# 932  Subduction zone / Continental crust (>25 km)
# 930  Subduction zone / Continental crust (>25 km)
# 931  Subduction zone / Continental crust (>25 km)
# ..                                            ...
# 957  Subduction zone / Continental crust (>25 km)
# 971        Rift zone / Continental crust (>25 km)
# 572  Subduction zone / Continental crust (>25 km)
# 3         Intraplate / Continental crust (>25 km)
# 10   Subduction zone / Continental crust (>25 km)
#
# [149 rows x 13 columns]

# %% [markdown]
# Oops! This didn't work as expected did it? Instead, we got the all the rows between the _indices_ of 0 and 10 which are not in any particular order now. When we sorted by Latitude, Pandas did not assign new indices and put the records in no particular order within a particular Latitude value. This is a "feature" of sorting functions. So... to get what we really wanted, which was the first 10 records in the NorthernToSouthern DataFrame, we can use the method **.iloc** instead of **.loc**.

# %%
NorthernToSouthern.iloc[0:10]
# Out:
#       Volcano Number               Volcano Name            Country  \
# 1361          377020  East Gakkel Ridge at 85°E  Undersea Features
# 1360          376010                  Jan Mayen             Norway
# 1359          375010           Kolbeinsey Ridge            Iceland
# 1355          373100      Tjornes Fracture Zone            Iceland
# 1354          373090              Theistareykir            Iceland
# 1352          373080                     Krafla            Iceland
# 1353          373082              Heidarspordar            Iceland
# 904           314060                Imuruk Lake      United States
# 1351          373070                Fremrinamar            Iceland
# 1350          373060                      Askja            Iceland
#
#      Primary Volcano Type   Activity Evidence Last Known Eruption  \
# 1361            Submarine   Evidence Credible             1999 CE
# 1360        Stratovolcano   Eruption Observed             1985 CE
# 1359            Submarine   Eruption Observed             1755 CE
# 1355            Submarine   Eruption Observed             1868 CE
# 1354               Shield      Eruption Dated             900 BCE
# 1352              Caldera   Eruption Observed             1984 CE
# 1353         Fissure vent  Confirmed Eruption             300 BCE
# 904             Shield(s)      Eruption Dated              300 CE
# 1351        Stratovolcano      Eruption Dated            1200 BCE
# 1350        Stratovolcano   Eruption Observed             1961 CE
#
#                         Region                   Subregion  Latitude  \
# 1361  Iceland and Arctic Ocean                Arctic Ocean    85.608
# 1360  Iceland and Arctic Ocean  Atlantic Ocean (Jan Mayen)    71.082
# 1359  Iceland and Arctic Ocean            North of Iceland    66.670
# 1355  Iceland and Arctic Ocean      Iceland (northeastern)    66.309
# 1354  Iceland and Arctic Ocean      Iceland (northeastern)    65.833
# 1352  Iceland and Arctic Ocean      Iceland (northeastern)    65.715
# 1353  Iceland and Arctic Ocean      Iceland (northeastern)    65.583
# 904                     Alaska            Alaska (western)    65.517
# 1351  Iceland and Arctic Ocean      Iceland (northeastern)    65.416
# 1350  Iceland and Arctic Ocean      Iceland (northeastern)    65.033
#
#       Longitude  Elevation (m)     Dominant Rock Type  \
# 1361     85.250          -3800      No Data (checked)
# 1360     -8.155           2197  Basalt / Picro-Basalt
# 1359    -18.500              5  Basalt / Picro-Basalt
# 1355    -17.118            -75  Basalt / Picro-Basalt
# 1354    -17.166            540  Basalt / Picro-Basalt
# 1352    -16.728            800  Basalt / Picro-Basalt
# 1353    -16.817            490                    NaN
# 904    -163.450            610  Basalt / Picro-Basalt
# 1351    -16.666            970  Basalt / Picro-Basalt
# 1350    -16.783           1080  Basalt / Picro-Basalt
#
#                              Tectonic Setting
# 1361      Rift zone / Oceanic crust (< 15 km)
# 1360      Rift zone / Oceanic crust (< 15 km)
# 1359      Rift zone / Oceanic crust (< 15 km)
# 1355      Rift zone / Oceanic crust (< 15 km)
# 1354      Rift zone / Oceanic crust (< 15 km)
# 1352      Rift zone / Oceanic crust (< 15 km)
# 1353      Rift zone / Oceanic crust (< 15 km)
# 904   Intraplate / Continental crust (>25 km)
# 1351      Rift zone / Oceanic crust (< 15 km)
# 1350      Rift zone / Oceanic crust (< 15 km)

# %% [markdown]
# Much better. Now we can see that there were lots of eruptions during the Holocene on Iceland.
#
# But to solve our indexing problem with **.loc[]**, we can **reset** the index back to the order of 0 to the length of the Dataframe.

# %%
# reset the indices to this list
# the drop=True drops the original index. Otherwise, it will be added into the DataFrame as a new column.
NorthernToSouthern = NorthernToSouthern.reset_index(drop=True)
NorthernToSouthern.head()
# Out:
#    Volcano Number               Volcano Name            Country  \
# 0          377020  East Gakkel Ridge at 85°E  Undersea Features
# 1          376010                  Jan Mayen             Norway
# 2          375010           Kolbeinsey Ridge            Iceland
# 3          373100      Tjornes Fracture Zone            Iceland
# 4          373090              Theistareykir            Iceland
#
#   Primary Volcano Type  Activity Evidence Last Known Eruption  \
# 0            Submarine  Evidence Credible             1999 CE
# 1        Stratovolcano  Eruption Observed             1985 CE
# 2            Submarine  Eruption Observed             1755 CE
# 3            Submarine  Eruption Observed             1868 CE
# 4               Shield     Eruption Dated             900 BCE
#
#                      Region                   Subregion  Latitude  Longitude  \
# 0  Iceland and Arctic Ocean                Arctic Ocean    85.608     85.250
# 1  Iceland and Arctic Ocean  Atlantic Ocean (Jan Mayen)    71.082     -8.155
# 2  Iceland and Arctic Ocean            North of Iceland    66.670    -18.500
# 3  Iceland and Arctic Ocean      Iceland (northeastern)    66.309    -17.118
# 4  Iceland and Arctic Ocean      Iceland (northeastern)    65.833    -17.166
#
#    Elevation (m)     Dominant Rock Type                     Tectonic Setting
# 0          -3800      No Data (checked)  Rift zone / Oceanic crust (< 15 km)
# 1           2197  Basalt / Picro-Basalt  Rift zone / Oceanic crust (< 15 km)
# 2              5  Basalt / Picro-Basalt  Rift zone / Oceanic crust (< 15 km)
# 3            -75  Basalt / Picro-Basalt  Rift zone / Oceanic crust (< 15 km)
# 4            540  Basalt / Picro-Basalt  Rift zone / Oceanic crust (< 15 km)

# %% [markdown]
# Another thing about indices: We can set the indices to one of the other column names, for example the "Volcano Name".

# %%
NorthernToSouthern = NorthernToSouthern.set_index('Volcano Name')
NorthernToSouthern.head()
# Out:
#                            Volcano Number            Country  \
# Volcano Name
# East Gakkel Ridge at 85°E          377020  Undersea Features
# Jan Mayen                          376010             Norway
# Kolbeinsey Ridge                   375010            Iceland
# Tjornes Fracture Zone              373100            Iceland
# Theistareykir                      373090            Iceland
#
#                           Primary Volcano Type  Activity Evidence  \
# Volcano Name
# East Gakkel Ridge at 85°E            Submarine  Evidence Credible
# Jan Mayen                        Stratovolcano  Eruption Observed
# Kolbeinsey Ridge                     Submarine  Eruption Observed
# Tjornes Fracture Zone                Submarine  Eruption Observed
# Theistareykir                           Shield     Eruption Dated
#
#                           Last Known Eruption                    Region  \
# Volcano Name
# East Gakkel Ridge at 85°E             1999 CE  Iceland and Arctic Ocean
# Jan Mayen                             1985 CE  Iceland and Arctic Ocean
# Kolbeinsey Ridge                      1755 CE  Iceland and Arctic Ocean
# Tjornes Fracture Zone                 1868 CE  Iceland and Arctic Ocean
# Theistareykir                         900 BCE  Iceland and Arctic Ocean
#
#                                             Subregion  Latitude  Longitude  \
# Volcano Name
# East Gakkel Ridge at 85°E                Arctic Ocean    85.608     85.250
# Jan Mayen                  Atlantic Ocean (Jan Mayen)    71.082     -8.155
# Kolbeinsey Ridge                     North of Iceland    66.670    -18.500
# Tjornes Fracture Zone          Iceland (northeastern)    66.309    -17.118
# Theistareykir                  Iceland (northeastern)    65.833    -17.166
#
#                            Elevation (m)     Dominant Rock Type  \
# Volcano Name
# East Gakkel Ridge at 85°E          -3800      No Data (checked)
# Jan Mayen                           2197  Basalt / Picro-Basalt
# Kolbeinsey Ridge                       5  Basalt / Picro-Basalt
# Tjornes Fracture Zone                -75  Basalt / Picro-Basalt
# Theistareykir                        540  Basalt / Picro-Basalt
#
#                                               Tectonic Setting
# Volcano Name
# East Gakkel Ridge at 85°E  Rift zone / Oceanic crust (< 15 km)
# Jan Mayen                  Rift zone / Oceanic crust (< 15 km)
# Kolbeinsey Ridge           Rift zone / Oceanic crust (< 15 km)
# Tjornes Fracture Zone      Rift zone / Oceanic crust (< 15 km)
# Theistareykir              Rift zone / Oceanic crust (< 15 km)

# %% [markdown]
# ## Sorting by awkward strings
#
# In this volcanic eruption data set, the dates for the last known eruption are the dates in CE or BCE or unknown, so we cannot sort by that column header. But we can first drop all the rows where the 'Last Known Eruption' is 'unknown', then split the dates on the space, multiply all the dates with 'BCE' in them by -1 and sort by the resulting column.
#
# Let's do that step by step:
#
# - to drop all the 'unknown' eruption dates, we can use the filtering statement:

# %%
EruptionData = pd.read_csv('data/GVP_Volcano_List_Holocene.csv',header=1) # read the original data
KnownEruptionDates = EruptionData[ EruptionData['Last Known Eruption'].str.contains('unknown')==False ]

# %% [markdown]
# To see if this worked, we can look at all the unique eruption dates and see if 'unknown' is still there:

# %%
KnownEruptionDates[KnownEruptionDates['Last Known Eruption'].str.contains('unknown')]
# Out:
# Empty DataFrame
# Columns: [Volcano Number, Volcano Name, Country, Primary Volcano Type, Activity Evidence, Last Known Eruption, Region, Subregion, Latitude, Longitude, Elevation (m), Dominant Rock Type, Tectonic Setting]
# Index: []

# %% [markdown]
# Nope. So now step 2:
#
# - To split a string on a particular key, in this case a space, we can use the syntax:
#
# EruptionData\['Last Known Eruption'\].str.split()

# %%
KnownEruptionDates['Last Known Eruption'].str.split().head()
# Out:
# 0    [8300, BCE]
# 1    [4040, BCE]
# 2      [Unknown]
# 3    [3600, BCE]
# 4     [104, BCE]
# Name: Last Known Eruption, dtype: object

# %% [markdown]
# Whoa! some of the entries are 'Unknown' and not 'unknown'. Sloppy! But we can handle that:

# %%
KnownEruptionDates = KnownEruptionDates[KnownEruptionDates['Last Known Eruption'].str.contains('Unknown')==False]

# %% [markdown]
# The **.str.split()** method returns a list with the stuff before the split key (by default, empty space) as the first element and the stuff after the key is the second.
#
# We can make two arrays, one for the date and one for the 'CE' or 'BCE' tag. We first make an array (using the DataFrame method **.values**, transpose the array and assign the first row to a dataframe column named 'date' and the second row to a column named 'CE/BCE'.

# %%
dates = KnownEruptionDates['Last Known Eruption'].str.split(' ',expand=True).transpose()
print(dates.values)
# Out:
# [['8300' '4040' '3600' ... '1911' '2016' '1962']
#  ['BCE' 'BCE' 'BCE' ... 'CE' 'CE' 'CE']]

# %%
# put in the 'date' column:
KnownEruptionDates['date'] = dates.values[0].astype('int')

# put in the 'CE/BCE' column:
KnownEruptionDates['CE/BCE'] = dates.values[1].astype('str')

# %% [markdown]
# Because Pandas read in the 'Last Known Eruption' as a string, we need to convert the first part to an integer (that is the **.astype('int')** above). This means we can multiply the date in records with 'BCE' by -1.

# %%
KnownEruptionDates.loc[KnownEruptionDates['CE/BCE'].str.contains('BCE'),'date'] = -1*KnownEruptionDates['date']

# Now we can sort the Dataframe by the newly created 'date' column from the oldest to the newest eruptions
KnownEruptionDates.sort_values(by='date').head()
# Out:
#       Volcano Number                   Volcano Name        Country  \
# 127           222161                   Igwisi Hills       Tanzania
# 561           283141                      Nantaisan          Japan
# 974           327812                       Red Hill  United States
# 964           324010  Black Butte Crater Lava Field  United States
# 1400          390022                         Berlin     Antarctica
#
#      Primary Volcano Type Activity Evidence Last Known Eruption  \
# 127   Pyroclastic cone(s)    Eruption Dated           10450 BCE
# 561         Stratovolcano    Eruption Dated            9540 BCE
# 974        Volcanic field    Eruption Dated            9450 BCE
# 964                Shield    Eruption Dated            8400 BCE
# 1400            Shield(s)    Eruption Dated            8350 BCE
#
#                        Region                              Subregion  \
# 127        Africa and Red Sea                       Africa (eastern)
# 561   Japan, Taiwan, Marianas                                 Honshu
# 974    Canada and Western USA                       USA (New Mexico)
# 964    Canada and Western USA                            USA (Idaho)
# 1400               Antarctica  Antarctica and South Sandwich Islands
#
#       Latitude  Longitude  Elevation (m)            Dominant Rock Type  \
# 127     -4.889     31.933           1146                       Foidite
# 561     36.765    139.491           2486  Andesite / Basaltic Andesite
# 974     34.250   -108.830           2300         Basalt / Picro-Basalt
# 964     43.183   -114.352           1478         Basalt / Picro-Basalt
# 1400   -76.050   -136.000           3478       Trachyte / Trachydacite
#
#                                   Tectonic Setting   date CE/BCE
# 127         Rift zone / Continental crust (>25 km) -10450    BCE
# 561   Subduction zone / Continental crust (>25 km)  -9540    BCE
# 974         Rift zone / Continental crust (>25 km)  -9450    BCE
# 964         Rift zone / Continental crust (>25 km)  -8400    BCE
# 1400       Intraplate / Continental crust (>25 km)  -8350    BCE

# %% [markdown]
# ## Concatenation

# %% [markdown]
# We've been working on a data set that only had Holocene data in it, but the same Smithsonian website has a data set for Pleistocene volcanic eruptions too. We can concatenate both data sets into a single DataFrame (as long as they have the same columns) like this:

# %%
HoloceneEruptionData = pd.read_csv('data/GVP_Volcano_List_Holocene.csv',header=1)
HoloceneEruptionData.head()
#print(len(HoloceneEruptionData))
# Out:
#    Volcano Number               Volcano Name  Country Primary Volcano Type  \
# 0          210010  West Eifel Volcanic Field  Germany              Maar(s)
# 1          210020            Chaine des Puys   France         Lava dome(s)
# 2          210030        Olot Volcanic Field    Spain  Pyroclastic cone(s)
# 3          210040   Calatrava Volcanic Field    Spain  Pyroclastic cone(s)
# 4          211003                    Vulsini    Italy              Caldera
#
#    Activity Evidence Last Known Eruption                          Region  \
# 0     Eruption Dated            8300 BCE  Mediterranean and Western Asia
# 1     Eruption Dated            4040 BCE  Mediterranean and Western Asia
# 2  Evidence Credible             Unknown  Mediterranean and Western Asia
# 3     Eruption Dated            3600 BCE  Mediterranean and Western Asia
# 4  Eruption Observed             104 BCE  Mediterranean and Western Asia
#
#         Subregion  Latitude  Longitude  Elevation (m)  \
# 0  Western Europe    50.170       6.85            600
# 1  Western Europe    45.775       2.97           1464
# 2  Western Europe    42.170       2.53            893
# 3  Western Europe    38.870      -4.02           1117
# 4           Italy    42.600      11.93            800
#
#                  Dominant Rock Type  \
# 0                           Foidite
# 1             Basalt / Picro-Basalt
# 2  Trachybasalt / Tephrite Basanite
# 3             Basalt / Picro-Basalt
# 4           Trachyte / Trachydacite
#
#                                Tectonic Setting
# 0        Rift zone / Continental crust (>25 km)
# 1        Rift zone / Continental crust (>25 km)
# 2       Intraplate / Continental crust (>25 km)
# 3       Intraplate / Continental crust (>25 km)
# 4  Subduction zone / Continental crust (>25 km)

# %%
PleistoceneEruptionData = pd.read_csv('data/GVP_Volcano_List_Pleistocene.csv',header=1) # read this in again
PleistoceneEruptionData.head()
#print(len(PleistoceneEruptionData))
# Out:
#    Volcano Number              Volcano Name  Country Primary Volcano Type  \
# 0          210801  South Harghita Mountains  Romania         Lava dome(s)
# 1          210802         Persani Mountains  Romania       Volcanic field
# 2          210803         Apuseni Mountains  Romania       Volcanic field
# 3          210804           Lucaret Basalts  Romania         Fissure vent
# 4          210805   Bakony-Balaton Highland  Hungary       Volcanic field
#
#    Activity Evidence  Last Known Eruption                          Region  \
# 0                NaN                  NaN  Mediterranean and Western Asia
# 1                NaN                  NaN  Mediterranean and Western Asia
# 2                NaN                  NaN  Mediterranean and Western Asia
# 3                NaN                  NaN  Mediterranean and Western Asia
# 4                NaN                  NaN  Mediterranean and Western Asia
#
#         Subregion  Latitude  Longitude  Elevation (m)  Dominant Rock Type  \
# 0  Western Europe    46.130     25.880           1289                 NaN
# 1  Western Europe    45.982     25.339            623                 NaN
# 2  Western Europe    45.930     22.880            353                 NaN
# 3  Western Europe    45.826     21.690            190                 NaN
# 4  Western Europe    46.920     17.630            600                 NaN
#
#                           Tectonic Setting
# 0  Intraplate / Continental crust (>25 km)
# 1  Intraplate / Continental crust (>25 km)
# 2  Intraplate / Continental crust (>25 km)
# 3  Intraplate / Continental crust (>25 km)
# 4  Intraplate / Continental crust (>25 km)

# %% [markdown]
# To concatenate the Holocene and Pleistocene data into a single Dataframe:

# %%
RecentEruptionData = pd.concat([HoloceneEruptionData,PleistoceneEruptionData])

# We can verify the results based on the Dataframe lengths
print(len(HoloceneEruptionData))
print(len(PleistoceneEruptionData))
print(len(RecentEruptionData))
# Out:
# 1424
# 1240
# 2664

# %%
RecentEruptionData.head()
# Out:
#    Volcano Number               Volcano Name  Country Primary Volcano Type  \
# 0          210010  West Eifel Volcanic Field  Germany              Maar(s)
# 1          210020            Chaine des Puys   France         Lava dome(s)
# 2          210030        Olot Volcanic Field    Spain  Pyroclastic cone(s)
# 3          210040   Calatrava Volcanic Field    Spain  Pyroclastic cone(s)
# 4          211003                    Vulsini    Italy              Caldera
#
#    Activity Evidence Last Known Eruption                          Region  \
# 0     Eruption Dated            8300 BCE  Mediterranean and Western Asia
# 1     Eruption Dated            4040 BCE  Mediterranean and Western Asia
# 2  Evidence Credible             Unknown  Mediterranean and Western Asia
# 3     Eruption Dated            3600 BCE  Mediterranean and Western Asia
# 4  Eruption Observed             104 BCE  Mediterranean and Western Asia
#
#         Subregion  Latitude  Longitude  Elevation (m)  \
# 0  Western Europe    50.170       6.85            600
# 1  Western Europe    45.775       2.97           1464
# 2  Western Europe    42.170       2.53            893
# 3  Western Europe    38.870      -4.02           1117
# 4           Italy    42.600      11.93            800
#
#                  Dominant Rock Type  \
# 0                           Foidite
# 1             Basalt / Picro-Basalt
# 2  Trachybasalt / Tephrite Basanite
# 3             Basalt / Picro-Basalt
# 4           Trachyte / Trachydacite
#
#                                Tectonic Setting
# 0        Rift zone / Continental crust (>25 km)
# 1        Rift zone / Continental crust (>25 km)
# 2       Intraplate / Continental crust (>25 km)
# 3       Intraplate / Continental crust (>25 km)
# 4  Subduction zone / Continental crust (>25 km)

# %%
RecentEruptionData.tail()
# Out:
#       Volcano Number  Volcano Name     Country Primary Volcano Type  \
# 1235          461838  Raja-Sabanda   Indonesia              Unknown
# 1236          461839      Hulunilo   Indonesia        Stratovolcano
# 1237          461840       Tungkat   Indonesia              Unknown
# 1238          464807  Ramu-Labumbu   Indonesia              Unknown
# 1239          590835     Discovery  Antarctica        Stratovolcano
#
#      Activity Evidence Last Known Eruption      Region  \
# 1235               NaN                 NaN   Indonesia
# 1236               NaN                 NaN   Indonesia
# 1237               NaN                 NaN   Indonesia
# 1238               NaN                 NaN   Indonesia
# 1239               NaN                 NaN  Antarctica
#
#                                   Subregion  Latitude  Longitude  \
# 1235                                Sumatra    -2.228    101.430
# 1236                                Sumatra    -2.418    101.776
# 1237                                Sumatra    -2.480    102.026
# 1238                   Lesser Sunda Islands    -8.416    118.207
# 1239  Antarctica and South Sandwich Islands   -78.374    165.015
#
#       Elevation (m) Dominant Rock Type  \
# 1235           2527                NaN
# 1236           2469                NaN
# 1237           1576                NaN
# 1238           1086                NaN
# 1239           2578                NaN
#
#                              Tectonic Setting
# 1235                                  Unknown
# 1236                                  Unknown
# 1237                                  Unknown
# 1238                                  Unknown
# 1239  Intraplate / Continental crust (>25 km)

# %% [markdown]
# So a lot less is known about the Pleistocene eruptions than the Holocene ones.

# %% [markdown]
# ## Merge

# %% [markdown]
# There is another data set on the Smithsonian Website that is interesting. It has a list of all the currently active volcanoes.

# %%
ActiveVolcanoes = pd.read_csv('data/ActiveVolcanoes.csv')
ActiveVolcanoes.head()
# Out:
#             Volcano        Country Eruption Start Date  \
# 0  Kuchinoerabujima          Japan         2020 Jan 11
# 1     Semisopochnoi  United States          2019 Dec 7
# 2      Nishinoshima          Japan          2019 Dec 5
# 3             Kikai          Japan          2019 Nov 2
# 4      Klyuchevskoy         Russia         2019 Oct 24
#
#          Eruption Stop Date  Max VEI
# 0  2020 Feb 13 (continuing)      NaN
# 1  2020 Feb 16 (continuing)      NaN
# 2  2020 Feb 15 (continuing)      1.0
# 3  2020 Feb 11 (continuing)      NaN
# 4  2020 Feb 19 (continuing)      NaN

# %% [markdown]
# There's a lot more information about each volcano in our HoloceneEruptionData DataFrame, which we could attach to the use Pandas **merge( )** method. There are many ways to use **merge**, but the idea is to identify what kind of join you want:

# %%
Image(filename='img/join-types.jpg',width=500)

# %% [markdown]
# We want to pair all the stuff from the Holocene volcanoes database with the ActiveVolcanoes data if it isn't already there ('Country' for example is in both).

# %%
MergedVolcanoes = ActiveVolcanoes.merge(KnownEruptionDates,how='left',left_on='Volcano',right_on='Volcano Name')
MergedVolcanoes.head()
# Out:
#             Volcano      Country_x Eruption Start Date  \
# 0  Kuchinoerabujima          Japan         2020 Jan 11
# 1     Semisopochnoi  United States          2019 Dec 7
# 2      Nishinoshima          Japan          2019 Dec 5
# 3             Kikai          Japan          2019 Nov 2
# 4      Klyuchevskoy         Russia         2019 Oct 24
#
#          Eruption Stop Date  Max VEI  Volcano Number      Volcano Name  \
# 0  2020 Feb 13 (continuing)      NaN        282050.0  Kuchinoerabujima
# 1  2020 Feb 16 (continuing)      NaN        311060.0     Semisopochnoi
# 2  2020 Feb 15 (continuing)      1.0        284096.0      Nishinoshima
# 3  2020 Feb 11 (continuing)      NaN        282060.0             Kikai
# 4  2020 Feb 19 (continuing)      NaN        300260.0      Klyuchevskoy
#
#        Country_y Primary Volcano Type  Activity Evidence Last Known Eruption  \
# 0          Japan    Stratovolcano(es)  Eruption Observed             2020 CE
# 1  United States        Stratovolcano  Eruption Observed             2020 CE
# 2          Japan              Caldera  Eruption Observed             2020 CE
# 3          Japan              Caldera  Eruption Observed             2020 CE
# 4         Russia        Stratovolcano  Eruption Observed             2020 CE
#
#                         Region                          Subregion  Latitude  \
# 0      Japan, Taiwan, Marianas          Ryukyu Islands and Kyushu    30.443
# 1                       Alaska                   Aleutian Islands    51.930
# 2      Japan, Taiwan, Marianas  Izu, Volcano, and Mariana Islands    27.247
# 3      Japan, Taiwan, Marianas          Ryukyu Islands and Kyushu    30.793
# 4  Kamchatka and Mainland Asia                Kamchatka Peninsula    56.056
#
#    Longitude  Elevation (m)            Dominant Rock Type  \
# 0    130.217          657.0  Andesite / Basaltic Andesite
# 1    179.580         1221.0         Basalt / Picro-Basalt
# 2    140.874           25.0  Andesite / Basaltic Andesite
# 3    130.305          704.0                      Rhyolite
# 4    160.642         4754.0         Basalt / Picro-Basalt
#
#                                   Tectonic Setting    date CE/BCE
# 0        Subduction zone / Oceanic crust (< 15 km)  2020.0     CE
# 1  Subduction zone / Intermediate crust (15-25 km)  2020.0     CE
# 2      Subduction zone / Crustal thickness unknown  2020.0     CE
# 3        Subduction zone / Oceanic crust (< 15 km)  2020.0     CE
# 4     Subduction zone / Continental crust (>25 km)  2020.0     CE

# %% [markdown]
# You see that if a particular column (say 'Country') is in both DataFrames, the first one gets renamed 'Country_x' and the other one 'Country_y'. To clean that up we can rename the first to 'Country', then delete (drop) the second one out of the DataFrame. We also want to delete the column 'Volcano Name' because it is redundant.

# %%
# inplace=True does the method 'in place' so we don't have to assign it to a new DataFrame
MergedVolcanoes.rename(columns={'Country_x':'Country'},inplace=True)
MergedVolcanoes.drop(['Country_y','Volcano Name'],axis=1,inplace=True)
MergedVolcanoes.head()
# Out:
#             Volcano        Country Eruption Start Date  \
# 0  Kuchinoerabujima          Japan         2020 Jan 11
# 1     Semisopochnoi  United States          2019 Dec 7
# 2      Nishinoshima          Japan          2019 Dec 5
# 3             Kikai          Japan          2019 Nov 2
# 4      Klyuchevskoy         Russia         2019 Oct 24
#
#          Eruption Stop Date  Max VEI  Volcano Number Primary Volcano Type  \
# 0  2020 Feb 13 (continuing)      NaN        282050.0    Stratovolcano(es)
# 1  2020 Feb 16 (continuing)      NaN        311060.0        Stratovolcano
# 2  2020 Feb 15 (continuing)      1.0        284096.0              Caldera
# 3  2020 Feb 11 (continuing)      NaN        282060.0              Caldera
# 4  2020 Feb 19 (continuing)      NaN        300260.0        Stratovolcano
#
#    Activity Evidence Last Known Eruption                       Region  \
# 0  Eruption Observed             2020 CE      Japan, Taiwan, Marianas
# 1  Eruption Observed             2020 CE                       Alaska
# 2  Eruption Observed             2020 CE      Japan, Taiwan, Marianas
# 3  Eruption Observed             2020 CE      Japan, Taiwan, Marianas
# 4  Eruption Observed             2020 CE  Kamchatka and Mainland Asia
#
#                            Subregion  Latitude  Longitude  Elevation (m)  \
# 0          Ryukyu Islands and Kyushu    30.443    130.217          657.0
# 1                   Aleutian Islands    51.930    179.580         1221.0
# 2  Izu, Volcano, and Mariana Islands    27.247    140.874           25.0
# 3          Ryukyu Islands and Kyushu    30.793    130.305          704.0
# 4                Kamchatka Peninsula    56.056    160.642         4754.0
#
#              Dominant Rock Type  \
# 0  Andesite / Basaltic Andesite
# 1         Basalt / Picro-Basalt
# 2  Andesite / Basaltic Andesite
# 3                      Rhyolite
# 4         Basalt / Picro-Basalt
#
#                                   Tectonic Setting    date CE/BCE
# 0        Subduction zone / Oceanic crust (< 15 km)  2020.0     CE
# 1  Subduction zone / Intermediate crust (15-25 km)  2020.0     CE
# 2      Subduction zone / Crustal thickness unknown  2020.0     CE
# 3        Subduction zone / Oceanic crust (< 15 km)  2020.0     CE
# 4     Subduction zone / Continental crust (>25 km)  2020.0     CE

# %% [markdown]
# Looks like it worked.

# %% [markdown]
# ## Using .unique() to find a list of categories, and string operations

# %% [markdown]
# Now that we have more information, we can start classifying these eruptions by type. For example, what tectonic settings are represented in this dataset? Pandas has a method called **.unique( )** that allows us to find all the unique values in a column.

# %%
MergedVolcanoes['Tectonic Setting'].unique()
# Out:
# array(['Subduction zone / Oceanic crust (< 15 km)',
#        'Subduction zone / Intermediate crust (15-25 km)',
#        'Subduction zone / Crustal thickness unknown',
#        'Subduction zone / Continental crust (>25 km)',
#        'Intraplate / Oceanic crust (< 15 km)',
#        'Rift zone / Continental crust (>25 km)', nan,
#        'Intraplate / Continental crust (>25 km)',
#        'Rift zone / Intermediate crust (15-25 km)'], dtype=object)

# %% [markdown]
# This tells us some useful information, including that some of the values are not a number (or 'nan').
#
# We can get rid of these using the method **.dropna()**. While we are at it, we can delete the rows with no information on 'Volcanic Explosivity Index' data (Max VEI).

# %%
MergedVolcanoes.dropna(subset=['Tectonic Setting'],inplace=True)
# The above is equivalent to MergedVolcanoes = MergedVolcanoes.dropna(subset=['Tectonic Setting']) without the inplace=True keyword

MergedVolcanoes.head()
# Out:
#             Volcano        Country Eruption Start Date  \
# 0  Kuchinoerabujima          Japan         2020 Jan 11
# 1     Semisopochnoi  United States          2019 Dec 7
# 2      Nishinoshima          Japan          2019 Dec 5
# 3             Kikai          Japan          2019 Nov 2
# 4      Klyuchevskoy         Russia         2019 Oct 24
#
#          Eruption Stop Date  Max VEI  Volcano Number Primary Volcano Type  \
# 0  2020 Feb 13 (continuing)      NaN        282050.0    Stratovolcano(es)
# 1  2020 Feb 16 (continuing)      NaN        311060.0        Stratovolcano
# 2  2020 Feb 15 (continuing)      1.0        284096.0              Caldera
# 3  2020 Feb 11 (continuing)      NaN        282060.0              Caldera
# 4  2020 Feb 19 (continuing)      NaN        300260.0        Stratovolcano
#
#    Activity Evidence Last Known Eruption                       Region  \
# 0  Eruption Observed             2020 CE      Japan, Taiwan, Marianas
# 1  Eruption Observed             2020 CE                       Alaska
# 2  Eruption Observed             2020 CE      Japan, Taiwan, Marianas
# 3  Eruption Observed             2020 CE      Japan, Taiwan, Marianas
# 4  Eruption Observed             2020 CE  Kamchatka and Mainland Asia
#
#                            Subregion  Latitude  Longitude  Elevation (m)  \
# 0          Ryukyu Islands and Kyushu    30.443    130.217          657.0
# 1                   Aleutian Islands    51.930    179.580         1221.0
# 2  Izu, Volcano, and Mariana Islands    27.247    140.874           25.0
# 3          Ryukyu Islands and Kyushu    30.793    130.305          704.0
# 4                Kamchatka Peninsula    56.056    160.642         4754.0
#
#              Dominant Rock Type  \
# 0  Andesite / Basaltic Andesite
# 1         Basalt / Picro-Basalt
# 2  Andesite / Basaltic Andesite
# 3                      Rhyolite
# 4         Basalt / Picro-Basalt
#
#                                   Tectonic Setting    date CE/BCE
# 0        Subduction zone / Oceanic crust (< 15 km)  2020.0     CE
# 1  Subduction zone / Intermediate crust (15-25 km)  2020.0     CE
# 2      Subduction zone / Crustal thickness unknown  2020.0     CE
# 3        Subduction zone / Oceanic crust (< 15 km)  2020.0     CE
# 4     Subduction zone / Continental crust (>25 km)  2020.0     CE

# %%
# Check if the rows with missing values (nan) of 'Tectonic Setting' are removed.
MergedVolcanoes['Tectonic Setting'].unique()
# Out:
# array(['Subduction zone / Oceanic crust (< 15 km)',
#        'Subduction zone / Intermediate crust (15-25 km)',
#        'Subduction zone / Crustal thickness unknown',
#        'Subduction zone / Continental crust (>25 km)',
#        'Intraplate / Oceanic crust (< 15 km)',
#        'Rift zone / Continental crust (>25 km)',
#        'Intraplate / Continental crust (>25 km)',
#        'Rift zone / Intermediate crust (15-25 km)'], dtype=object)
