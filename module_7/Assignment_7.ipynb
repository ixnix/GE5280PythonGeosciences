# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Pandas DataFrames
# - Import the file 'DeltaTime.txt' into a panda DataFrame
# - Get acquainted with the DataFrame:
#     - print out the name of the columns
#     - print out the first 20 lines of the DataFrame
#     - change the column headers to more descriptive names
#     - print out the new column headers
# - Add a new column to the dataframe by converting the P wave arrival from minutes and seconds to decimal minutes
# - Calculate the S wave arrival by:
#     - Converting S-P to decimal minutes
#     - Adding P in decimal minutes to S-P in decimal minutes
# - Save the updated dataframe into a CSV file.

# %%
# Write your code here

# %% [markdown]
# ### 2. Matplotlib.pyplot
# - Plot Degrees against decimal minutes for both the Primary wave arrival and the Secondary wave arrival
# - Color the primary wave green and label it "P wave"
# - Color the secondary wave blue and label it "S wave"
# - Add a legend in the lower right hand corner of your figure
# - Add a title to your figure
# - Add a label to the x and y axis
# - Save the figure in png format
# - Remove the legend from your plot. Instead, insert the text  "Primary wave" and "Shear wave" above the appropriate line
# - Save the new figure in png format (using a different file name)

# %%
# Write your code here

# %% [markdown]
# ### 3. Pandas methods and filtering
# - Import the file 'minutes_velocity.csv' into a Pandas DataFrame, _df_.
# - Print the column names in _df_ using the **.columns** attribute
# - Print the dtypes of each column in _df_ using **.dtypes** attribute
# - Calculate the median velocity in _df_ (use the function **.median()** method). Print out the median value.
# - Calculate the mean velocity in _df_ (use the **.mean()** method). Print the mean value.
# - Filter _df_ to select all the velocities that fall between the median and mean; Name it _df1_.
# - Calculate the length and shape of _df1_.
# - Filter _df_ to select the data within the first minute, as _df2_.
# - Calculate the mean and standard deviation of velocity in _df2_ (use the **std()** method) within the first minute.
# - Test if the maximum velocity of _df2_ is larger than the mean velocity plus two times the standard deviation.

# %%
# Write your code here

# %% [markdown]
# ### 4. Great Circle Function
# - Write a function **colat()** that takes _lat_ (in degrees) as a single argument, and converts them to colatitude (in radians)
# - Write another function **londiff()**, that takes two longitudes, _lon1_ and _lon2_ (in degrees), and returns the difference between them (in radians)
# - Re-write the function **great_circle()** that calls the two functions defined above, and returns the separation in degrees (**Hint:** remember that NumPy assumes that the units are in radians)
# - Use your new function **great_circle()** to find the angular difference between where you were born and GLRC (latitude = 47.12065361037676, longitude = -88.54659882775128).
# - There are roughly 111 km in one degree, how many kilometers is the distance between your birthplace and GLRC?

# %%
# Write your code here
