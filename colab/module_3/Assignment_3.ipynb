# %% [markdown]
# # Assignment 3: Data Structures
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_3/Assignment_3.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Conceptual
# - Give an example of when you would use a set.
# - Give an example of when you would use a tuple.
# - Give an example of when you would use the built-in function, range( ).

# %% [markdown]
# Type your answer here:

# %% [markdown]
# ### 2. List
# - Create an empty list called _oceans_
# - Append the following oceans to the list: Arctic, Atlantic, Pacific, Indian, Southern.
# - Print the ocean at **index** 3 in the list.
# - Print the last element of your list.
# - Make a shallow copy of _oceans_ called _seas_ and a deep copy of _oceans_ called  _big_water_. Try to modify the copies. Verify that the shallow copy refers to the same underlying object while the deep copy makes an independent object.
# - Apply the method **.sort()** to _seas_ and then print the list.
# - Find the index value of element 'Pacific' in _seas_.

# %%
# Write your code here

# %% [markdown]
# For the following questions, write **a single line of code** that will produce the given output.

# %%
mylist = [3, 5, 6, 12]

# Write your code here

# %% [markdown]
# Your output should be: 3

# %%
mylist = [3, 5, 6, 12]

# Write your code here

# %% [markdown]
# Your output should be: 12

# %%
mylist = [3, 5, 6, 12]

# Write your code here

# %% [markdown]
# Your output should be: [5, 6, 12]

# %%
mylist = [3, 5, 6, 12]

# Write your code here

# %% [markdown]
# Your output should be: [12, 6, 5, 3]

# %%
mylist = [3, 5, 6, 12]

# Write your code here

# %% [markdown]
# Your output should be: [3, 5, 6, 12, 48]

# %%
mylist = [3, 5, 6, 12]

# Write your code here

# %% [markdown]
# Your output should be: [3, 6, 12]

# %% [markdown]
# ### 3. range()
# - Use the function **range( )** to create a list with a “range” of numbers from 0 up to (but not including) 100, increment by 20 and print the results.
# - Print the length of the list.

# %%
# Write your code here

# %% [markdown]
# ### 4. Tuples
# - Create a tuple called _continents_ with the following elements: Asia, Africa, Europe, Australia, North America, South America, and Antarctica.
# - Print out the third **element** (not index)  in the tuple.
# - Attempt to change the second **element** (not index) in place (this should throw an error).

# %%
# Write your code here

# %% [markdown]
# ### 5. Sets
# - Create a set from the _oceans_ list you created in Question 2 above.
# - Print out the set of oceans.
# - Test if 'Indian' is in the set using the **in** keyword. It should print a boolean value.

# %%
# Write your code here

# %% [markdown]
# - Define two lists
#     - list1 contains 'CA', 'GA', 'IA', 'MI', 'MO'
#     - list2 contains 'MI', 'NY', 'WI', 'GA', 'NV'
# - Create two sets, called _set1_ and _set2_ from _list1_ and _list2_, respectively
# - Create a new set _set3_ by merging _set1_ and _set2_ using the union() method
# - Find the states that exist in both _set1_ and _set2_ using the intersection() method
# - Find the states that exist in _set1_ but not in _set2_ using the difference() method
# - Convert _set1_ to a list
# - Convert _set2_ to a tuple

# %%
# Write your code here

# %% [markdown]
# ### 6. Dictionaries
#
# - Create a dictionary called **geology** with keys “Igneous” and “Metamorphic”.  The _values_ of these keys should be the definition of these words.
# - Print the value for the key "Igneous"
# - Add a new key-value pair “Sedimentary” with its definition.
# - Print all of the keys using the method _keys()_
# - Print all of the values using the method _values()_

# %%
# Write your code here
