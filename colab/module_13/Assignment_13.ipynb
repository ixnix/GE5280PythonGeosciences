# %% [markdown]
# # Assignment 13: Cartopy
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_13/Assignment_13.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %%
# !pip install -q cartopy

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Mercator projection
# - Make a mercator projection with latitude bounds of $\pm$ 80.
# - Color the oceans aqua and the continents coral
# - Draw on parallels and meridians at 15 degree intervals
# - Place a pentagon where you were born and set the markersize to 15.

# %%
# Write your code here

# %% [markdown]
# ### 2. Orthographic maps
# - Make an orthographic map for the other side of the world by setting lon_0 and lat_0 to 180 and -80 respectively
# - Color the continents black
# - Plot a large magenta square at the South Pole (-90, 170)

# %%
# Write your code here

# %% [markdown]
# ### 3. Lambert Conformal Conic maps
# - Make a Lambert conformal conic projection with the boundaries 0-40N and 110E-160E.
# - Add the continents to your map
# - Add reasonable latitude and longitude grid lines and label them.
# - Plot the earthquakes in the data file **last5Years.csv** as black triangles.
# - Change the size of the markers based on depths - you can use the same depth bins as in the lecture, or use your own bins.

# %%
# Write your code here

# %% [markdown]
# ### 4. Robinson projection
# - Use the data from usgs_earthquakes_2014.csv to recreate the attached map. The file is downloaded from http://www.ldeo.columbia.edu/~rpa/usgs_earthquakes_2014.csv.
# - Steps:
#     - Use pandas to read in the data file and filter the top 30 earthquakes of 2014 based on magnitude.
#     - Create a map using the Robinson projection in Cartopy.
#     - Plot the earthquake locations using longitude and latitude columns.
#     - Use the magnitude (mag) column to color code the earthquakes.
#     - Add a map background using stock_img().
#     - Apply the YlOrRd colormap to represent earthquake magnitude.
#     - Include a colorbar to indicate the magnitude scale.
#     - Optional: Customize markers (size or shape) to emphasize higher magnitude events.

# %%
# Write your code here
