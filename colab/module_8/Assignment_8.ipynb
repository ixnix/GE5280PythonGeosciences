# %% [markdown]
# # Assignment 8: Data Wrangling
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_8/Assignment_8.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Indexing, sorting, and plotting Earthquake data
#
# - Read the CSV file `EruptionData.csv` using Pandas and assign it to a DataFrame named **dfVol**.
# - Use the **head()** method to display the first 10 rows of **dfVol**.
# - Find the list of unique volcano names by applying the **.unique()** method on the **Volcano Name** column. Store the result in volNames.
# - Initialize a Pandas Series **NEvent** to store the number of eruptions for each volcano. Use **volNames** as the index and set **dtype=int**. Refer to the [Pandas Series documentation](https://pandas.pydata.org/docs/reference/api/pandas.Series.html) for guidance.
# - Loop over **volNames** using a **for** loop. For each volcano name, filter **dfVol** to select its records, calculate the number of eruptions using **len()**, and store the value in **NEvent**.
# - Sort **NEvent** with **.sort_values()** to identify the volcano with the most eruptions.
# - Filter **dfVol** for this most active volcano and assign it to **dfMostActive**.
# - Sort **dfMostActive** by the **VEI** column using **.sort_values()** to find the top 5 most explosive eruptions. Print the **Start Year** and **VEI** of these events.
# - Remove rows in **dfMostActive** where **VEI** is missing using **.dropna()**.
# - Filter **dfMostActive** to include only eruptions after the year 1000 and store in **dfRecent**.
# - Use **plt.scatter()** to plot **Start Year** (x-axis) vs. **VEI** (y-axis) from **dfRecent**. Represent each eruption with unfilled red circles (set facecolors='none' and edgecolors='r').

# %%
# Write your code here

# %% [markdown]
# ### 2. Indexing and filtering volcanology data
#
# - Read the CSV file `GVP_Volcano_List_Holocene.csv` using Pandas and assign it to a DataFrame named **dfVol**.
# - Use **.iloc[]** to find the **'Volcano Name'** and **'Country'** of the first 5 volcanoes in the file. Only output the requested columns.
# - Set the column **'Volcano Name'** as the index of **dfVol**.
# - Use **.loc[]** to find the **'Last Known Eruption'** of **'Etna'**.
# - Use **.loc[]** to find the **'Primary Volcano Type'** and **'Tectonic Setting'** of **'St. Helens'**.
# - Find the list of countries (unique values only) with eruptions in year 2018. Clean the **'Eruption Year'** column if needed (see lecture note).
# - Find the list of **'Primary Volcano Type'** (unique values only) for all volcanoes.
# - Find the list of **'Primary Volcano Type'** (unique values only) for all volcanoes located between latitudes 10°S and 10°N.

# %%
# Write your code here

# %% [markdown]
# ### 3. Analyze weather data using Pandas (Numpy solutions are unacceptable)
#
# - Read the file `Avg_Rain.txt` into a Pandas DataFrame **dfrain** using **pd.read_csv()**. Set dtype=float, header=None, and name the column **rain**.
# - Create a new column **'year'** in **dfrain** and assign a list of years starting from 1931, incremented by 1, matching the length of **dfrain** (using **np.arange()**).
# - Calculate the maximum, minimum, and average of the **'rain'** column using appropriate DataFrame methods.
# - Create a new column **'rainAnomaly'** by subtracting the average rainfall from each value in the **'rain'** column.
# - Verify that the average of **'rainAnomaly'** is zero.
# - Use **.loc[]** to find the year corresponding to the maximum rainfall.
# - Use **.loc[]** to find the rainfall in the year 2000.
# - Set the **'year'** column as the index of **dfrain**.
# - Use **.loc[]** again to find the rainfall in the year 2000 using the new index.
# - Use the **.idxmax()** method to find the year corresponding to the maximum rainfall.
# - Slice **dfrain** between years 2000 and 2010 using **.loc[]** and name the result **dfrain2000s**.
# - Calculate the median of the **'rain'** column in **dfrain2000s**.
# - In **dfrain2000s**, set the **'rain'** values to zero if they are below the median value.

# %%
# Write your code here
