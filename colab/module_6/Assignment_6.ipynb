# %% [markdown]
# # Assignment 6: NumPy
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_6/Assignment_6.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Numpy constants
# - Calculate the area of a circle with a radius of 2. Use the pi constant in Numpy.
# - Create a python list of three numbers: 1, 5, 10. Name it **mylist** and print it out.
# - Use the np.log() method to calculate the log values using the list as input. Name the output **myarr** and print it out.
# - Test if each element of myarr is greater than 2. The result should be an array of boolean values.

# %%
# Write your code here

# %% [markdown]
# ### 2. Matplotlib.pyplot
# - Import **matplotlib.pyplot** as **plt**
# - Create a list of angles from 0 to 2*np.pi called **thetas_in_radians** using the **np.arange()** function.
# - Use **thetas_in_radians** to generate an array of cosines (using the appropriate **Numpy** function).
# - Create a line plot with **thetas_in_radians** on the X axis and your array of cosines on the Y axis. Draw the cosines with a black solid line.
# - Add x-axis label 'Angle in radians', and y-axis label 'Cosine'.
# - Set the y limits to -1 and 1

# %%
# Write your code here

# %% [markdown]
# ### 3. Generate arrays
# - Use the **np.arange()** method to generate an array of angles from -180.0 up to 180.0 by intervals of 30.0. Note that the ending point 180.0 is included. Print the dtype attribute of the array. Is it float or integer?
# - If the above step gives float numbers, modify your code to generate an integer array. Hint: use the **dtype** keyword in **np.arange()**.
# - Use **np.linspace()** to generate an array of 16 equally spaced values between -180 and 180. Print it out.

# %%
# Write your code here

# %% [markdown]
# ### 4. Array reshape
# - Load the data file _earthquakeLocations.txt_ into a **NumPy** array. The data file contains the latitude and longitude of 10 different earthquakes.
# - Use the Numpy attribute to print out the size of the array you imported.
# - Convert the shape of the array to 2x10 using two different methods: **np.reshape()** and **np.transpose()**.
# - Print out the converted arrays and find out if they are the same as each other.

# %%
# Write your code here

# %% [markdown]
# ### 5. Array slicing
# - Load the data file _earthquakeLocations.txt_ into a NumPy array. The data file contains the latitude and longitude of 10 different earthquakes.
# - Slice the first seven values of longitude from the array, and assign it in a new variable **lons**. Note that **lons** should contain longitudes only.
# - Print the dtype and size attributes of **lons**.
# - Use boolean indexing to find the longitude values west of 150 deg W. Print them out.
# - Save those longitude values into a text file named 'lons.txt'.

# %%
# Write your code here

# %% [markdown]
# ### 6. Array methods
# - Use the **np.random.randint()** method to generate a 5x4 integer array between -10 and 10; Name it **arr1**. The method takes three arguments: _low_, _high_, and _size_. Be aware that _high_ is exclusive! See full description and examples [here](https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html).
# - Print out **arr1**, followed by an empty line ('\n').
# - Use boolean indexing to find the positive values in **arr1**. Your output should be a 1D array.
# - Use boolean indexing to find the values in **arr1** between -5 and 5. Your output should be a 1D array.
# - Use the proper Numpy method to find the maximum values along axis 1.
# - Use the proper Numpy method to find the indices corresponding to the maximum value along axis 1.
# - Use np.where() to make a new array, **arr2**. **arr2** should take the value of **arr1** when **arr1** is between -5 and 5, otherwise take the value of np.nan.

# %%
# Write your code here

# %% [markdown]
# ### 7. Weather data analysis
# - Read in the annual average rainfall from the file 'Avg_Rain.txt' into a numpy ndarray, _rain_.
# - Print out the **shape**, **dtype** attributes of the array
# - Calculate the maximum, minimum, and mean of _rain_ using proper numpy ndarray methods; Name them as _rainMax_, _rainMin_, and _rainAvg_ respectively; Print them out.
# - Calculate the anomaly of annual rainfall by subtracting _rainAvg_ from _rain_; Name the result as _rainAnomaly_.
# - Create an array of integers _years_ from 1931 to 2016. Note that _years_ should have the same length as _rain_.
# - Use boolean indexing to find the rainfall of year 2000.
# - Use boolean indexing to find the years in which _rain_ is higher than 45.
# - Find out the year corresponding to the minimum of _rain_ using the **argmin()** method; Name it _yearMin_. Print out the results.
# - Find out the year corresponding to the maximum of _rain_ using the **argmax()** method; Name it _yearMax_. Print out the results.
# - Use boolean indexing to slice the _rain_ array between year 2000 and 2010; Name it _rain2000s_ and print out the results. (hint: use & to combine multiple boolean conditions)
# - Calculate the median value of _rain2000s_ using **np.median()**; Name it _rainMed_ and print out the results.
# - Use **np.where()** to change _rain2000s_ to zero if it's lower than _rainMed_; Otherwise keep it unchanged. Print out _rainfall2000s_.

# %%
# Write your code here

# %% [markdown]
# ### 8. Plot weather data
# - Plot _rainAnomaly_ against _years_.
# - Set line style to solid, marker type to square, linewidth to 2, and color to black (hint: use linestyle, marker, linewidth and color keywords in **plt.plot()**).
# - Set the $x$ and $y$ axis labels as 'Year' and 'Rainfall Anomaly', respectively.
# - Set the xticks and yticks fontsize to 12.
# - Set the x limits to 1930 and 2017; and y limits to -30 and 30.
# - Add a horizontal line at _rainAnomaly_=0 using **plt.axhline()**; Set the line style to dashed, color to gray, linewidth to 2.
# - Add a text note on the plot, 'Max at X' (where X is the value of _yearMax_) at the position of x=_yearMax_ and y=_rainMax_-_rainAvg_.
# - Set the text color to red and fontsize to 'large'.

# %%
# Write your code here
