# %% [markdown]
# # Assignment 11: Lambda Functions
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_11/Assignment_11.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Lambda functions
# - Write a regular function **SQa** that takes one argument and returns the square of that argument.
# - Write a lambda function called **SQb** that calculates the square root of an input.
# - Call your function **SQa** with the value 4. Print the output.
# - Call your function **SQb** with the value 4. Print the output.

# %%
# Write your code here

# %% [markdown]
# ### 2. map()
# - Use range() to create a list of numbers from 0 to 300 in intervals of 10.
# - Use range() to create a list of numbers from 0 to 90 in intervals of 3.
# - Write a lambda function that calculates the difference between two numbers.
# - Apply **map( )** and the anonymous function to the two lists you defined
# - Print the results of the **map( )** function - remember to use **list( )** to make a list from the list generator returned by **map( )**

# %%
# Write your code here

# %% [markdown]
# ### 3. filter()
# - Create the following dictionary: lastEruption = {"Mt.Etna": 2017, "Mt. St. Helens" :1980, "Mt. Erebus": 2017, "Mount Teide" : 1909, "Mt. Hood": 1800}
# - Define a lambda function **active** that returns a boolean. It should return **True** if a volcano has erupted in the last 10 years.
# - Use the function **filter()**, the function **active**, and _lastEruption_ to determine which volcanoes have erupted in the last 10 years.
# - Print the names of the recently active volcanoes using filter()

# %%
# Write your code here

# %% [markdown]
# ### 4. reduce()
# - Write a lambda function that finds multiples of 7.
# - Write another lambda function that returns the greater of two numbers.
# - Use the two lambda functions with  **filter()**  and **reduce()** to find the greatest multiple of 7 in the following list:
#
#     \[234, 55, 40, 777, 100, 450, 335, 308, 693, 333, 405, 303, 109, 321, 565, 891\]
#
# - Print the result.

# %%
# Write your code here
