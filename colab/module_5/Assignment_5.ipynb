# %% [markdown]
# # Assignment 5: Functions
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_5/Assignment_5.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Doc string
# - Create a function  **greeting( )**. Include a doc string that explains what the function does
# - In the body, use the command **print ('Hi there')**
# - Print out the docstring with **help(greeting)**

# %%
# Write your code here

# %% [markdown]
# ### 2. Functions
# - Create a function called **circleArea( )** . The function should take a radius as an argument and return the area of a circle with that radius ($A=\pi r^2$). Include a doc string (as ALWAYS).
# - Call the function and calculate the area for a radius of 5.

# %%
# Write your code here

# %% [markdown]
# - Create a function called **add_them_up()** that takes an unspecified number of input floating point or integer arguments and returns their sum.
# - Call the function with different numbers of arguments and print the sum, e.g., 3 integers, 4 float numbers, and 5 numbers mixed with integers and floats.

# %%
# Write your code here

# %% [markdown]
# ### 3. Scope of variables
#
# Local variables
# - Define a variable **myName** with your name
# - Print **myName**
# - Define a function **greeting( )** that sets myName to "Douglass Houghton", and prints a string "Hello" and the variable **myName**
# - Call the function **greeting( )** and print the output
# - Print **myName** again
# - Has the value of **myName** changed after calling the function **greeting( )**?

# %%
# Write your code here

# %% [markdown]
# Global variables
# - Define a variable **myName** with your name
# - Print **myName**
# - Define a function **greeting( )** that sets a global variable **myName** to "Douglass Houghton", and prints a string "Hello" and the variable **myName**
# - Call the function **greeting( )** and print the output
# - Print **myName** again
# - Has the value of **myName** changed after calling the function **greeting( )**?

# %%
# Write your code here
