# %% [markdown]
# # Assignment 12: Object-Oriented Programming
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_12/Assignment_12.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Define classes
# - Create a class called **Rectangle** with width and height (**w**,**h**) as attributes
# - Include a docstring
# - Define two methods: **area** and **perimeter**
#     - area calculates the area of a rectangle
#     - perimeter calculates the perimeter of a rectangle
#     - include a docstring for each method
# - Create a new instance of the Rectangle class with w=4 and h=6.
# - Create a second instance of the Rectangle class with w=4 and h=4
# - Call the method **area()** on your first Rectangle object and assign to a new variable. Print out the result.
# - Call the method **perimeter()** on your second Rectangle object and assign to a new variable. Print out the result.

# %% [markdown]
# **Hint**:
#
# If you have changed a module and you need to import the changes into the jupyter notebook, execute the command:
#
# **from importlib import reload**
#
# Then you can use this command to refresh your module in the notebook:
#
# **reload(yourModuleName)**

# %%
# Write your code here

# %% [markdown]
# ### 2. Save classes in modules
# - Save the Circle class from the lecture note and the Rectangle class defined above into a module called **Shapes.py**. Now you can import and re-use it whenever needed.
# - Start a new code cell. Import the **Shapes** module
# - Create a new instance of the **Rectangle** class with width of 2 and height of 4.
# - Create a new instance of the **Circle** class with a radius of 5.
# - Call the methods **area()** and **perimeter()** of your Rectangle instance, and print out the results.
# - Call the methods **area()** and **circumference()** of your Circle instance, and print out the results.

# %%
# %%writefile Shapes.py
# add the Circle and Rectangle classes here

# %%
# import the Shapes module create new instances in this cell
