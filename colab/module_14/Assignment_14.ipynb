# %% [markdown]
# # Assignment 14: Seaborn
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_14/Assignment_14.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# ## Assignment 14
#
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Kernel Density Estimates and Jointplots
#
# - Use **pandas** to read in the tab-separated file **ZirconData.txt**. These data were downloaded from the [Pangaea database](https://doi.pangaea.de/10.1594/PANGAEA.847015).
# - The dataset contains Lead-Lead and Uranium-Lead age dates for zircons from Dronning Maud Land, Antarctica. The zircon ages reflect two stages of growth associated with two mountain-building events in the region.
# - Identify the columns:
#   - **Age dated [ka] (Age, 206Pb/238U Lead-Uranium)**
#   - **Age dated [ka] (Age, 207Pb/206Pb Lead-Lead)**
#   Compute and print the **mean** of each column.
# - Use **plt.hist()** to plot histograms of both age systems.
# - Use **sns.kdeplot()** to plot kernel density estimates (KDEs) of both age systems. Experiment with the **bw** (bandwidth) argument to see how it affects the smoothness of the KDE. The bandwidth controls how tightly the KDE fits the data, similar to the bin size in a histogram.
# - Use **sns.jointplot()** to create a 2D kernel density plot of the two age systems to visualize their joint distribution.

# %%
# Write your code here

# %% [markdown]
# ### 2. Box and Violin Plots
#
# - Use **sns.boxplot()** to plot the Pb-U ages for each sample (use the **'Sample ID'** column for the x-axis).
# - Add a horizontal line representing the mean Pb-U age of the entire dataset using **plt.axhline()**.
# - Use **sns.violinplot()** to plot the distribution of Pb-U ages for each sample.
# - Overlay a **swarm plot** on top of the violin plot using **sns.swarmplot()** to show individual data points.
# - Compare the boxplot and violin plot: which one conveys more information about the data distribution in this dataset, and why?

# %%
# Write your code here

# %% [markdown]
# ### 3. Pairplots
#
# - Filter the DataFrame to include only rows where **207Pb/206Pb** and **206Pb/238U** are less than 0.5.
# - Use **sns.pairplot()** to plot the four elemental ratios: **232Th/238U**, **207Pb/206Pb**, **207Pb/235U**, and **206Pb/238U** against one another.
# - Examine the pairplot: do you observe any **bimodal distributions** in these variables?
# - Identify any pairs of ratios that appear to be **strongly correlated**.

# %%
# Write your code here
