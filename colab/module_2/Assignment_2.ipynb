# %% [markdown]
# # Assignment 2: Variables
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_2/Assignment_2.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. General concepts
# - Insert a markdown cell into your notebook and answer the following questions:
# - Why are descriptive variable names useful?
# - What are _reserved words_ and why can't you use them as variable names?

# %%
# Write your code here

# %% [markdown]
# ### 2. Variables
# - Insert a code cell into your notebook
# - Define a variable that stores the value of pi (3.1415)
# - Define a variable **radius** and set it to a floating point number: 1.5
# - Define a string variable **mystr** that stores this string: " is the circumference of a circle with radius "

# %%
# Write your code here

# %% [markdown]
# ### 3. Operations
# - Insert another code cell.
# - Calculate the circumference of a circle using the variables you defined earlier and store the answer in a new variable: **circumference**.
# - print your new variable.

# %%
# Write your code here

# %% [markdown]
# ### 4. Variable types
# - Convert all your variables (**circumference** and **radius**) into strings
# - Use the **+** operator to add the converted string and **mystr** together to make this string: **X** is the circumference of a circle with radius of **Y**. (where **X** and **Y** are the converted strings in the prior step.)

# %%
# Write your code here

# %% [markdown]
# ### 5. String operations
# - Define a variable to store this string: "Michigan Technological University"
# - Print the first 7 characters
# - Print the 4th through 10th characters
# - Print the substring at positions 8 to 19
# - Print the substring at positions 23 to the end
# - Print the substring starting at position 2 to the end at an increment of 2

# %%
# Write your code here

# %% [markdown]
# ### 6. Add together
# - Create an integer variable **depth** and set it to 6.
# - Create a string variable **planet** and set it to “Earth”.
# - Convert the variable **depth** into a string.
# - Create a new variable **ocean_depth** and set it to the string: “The average ocean depth on Earth is 6 km”, using the **depth** and **planet** variables.
# - Print the variable **ocean_depth**.

# %%
# Write your code here
