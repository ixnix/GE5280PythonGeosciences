# %% [markdown]
# # Assignment 9: Data Aggregation
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ixnix/GE5280PythonGeosciences/blob/main/colab/module_9/Assignment_9.ipynb)
#
# *Run this notebook on Google Colab — no setup required.*

# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### Aggregating Earthquake data
#
# ### 1. Eruption Counts by Volcano
# - Read the file `EruptionData.csv` into a DataFrame named **dfVol**.
# - Use **groupby()** to calculate the number of eruptions for each volcano; Store as **NEvent**.
# - Extract the top 10 volcanoes with the most eruptions; Store as **NEvent10**.
# - Create a bar plot of **NEvent10**, with the number of eruptions in Y-axis and volcano name in X-axis

# %%
# Write your code here

# %% [markdown]
# ### 2. Eruption Counts by Year
# - Use **groupby()** to calculate the number of eruptions for each Start Year; Store as **NYr**.
# - Use **.loc[]** to filter **NYr** for the years 1950–2000; Store as **NYr50**.
# - Create a line plot for **NYr50**, with the number of eruptions in Y-axis and Start Year in X-axis. Use black squares with a solid black line.

# %%
# Write your code here

# %% [markdown]
# ### 3. Filtering by VEI and Year
# - Extract all rows from **dfVol** with VEI>=2 and for years between 1800 and 2000; Store as **dfVol200**.
# - Use **.value_counts()** to compute the number of eruptions in **dfVol200** for each VEI value
# - Create a line plot using VEI as X-axis, and number of eruptions as Y-axis. Use red circles with a dashed red line.

# %%
# Write your code here

# %% [markdown]
# ### 4. Grouping by Latitude Bands
# - Cut **dfVol200** into latitude bins at 10° intervals from -90° to +90° using **pd.cut()**.
# - Use **groupby()** to count eruptions in each latitude bin; Store as **NLat**.
# - Create a horizontal bar plot of **NLat**, with the number of eruptions in X-axis and latitude bin in Y-axis.

# %%
# Write your code here

# %% [markdown]
# ### 5. Aggregating by Region and Volcano Type
# - Find the strongest eruption event (highest VEI) for each **Region**.
# - Find the strongest eruption event for each combination of **Region** and **Volcano Type**. Use both Region and Volcano Type as the groupby columns.
# - Find both the strongest eruption event and total number of eruptions for each **Region**. Use `agg()` to compute multiple statistics in one step.

# %%
# Write your code here
