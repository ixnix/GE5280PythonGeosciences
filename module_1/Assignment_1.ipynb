# %% [markdown]
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Practice with inserting cells
# - Insert a cell
# - Change it to ‘Markdown’ and type some notes. You can type section headers, bullets, numbered lists and other things with special formatting. See instructions at this link: https://www.markdownguide.org/cheat-sheet/
# - Run the cell to typeset your notes. If you want to change them, just double click on the cell, type away, then run it again.

# %% [markdown]
# ### 2. Practice with markdown cells
# - If you see plain text in one of the cells in the lecture notebook, just double click on it and all will be revealed.
# - Try double clicking on THIS cell to see how to make bulleted lists
# - Make a bullet list of your own, and then run it.

# %% [markdown]
# ### 3. Practice with code cells
# - Insert another cell, keeping it the default of Code.
# - Type in the cell: print("Hello World"). Note that you can also use single quotes for strings, i.e., print('Hello World').
# - Run that cell.
# - Congratulations! You just wrote your first line of python code.

# %% [markdown]
# ### 4. Commands within a jupyter notebook
# - import the **os** package by running the cell below (don't worry about what this is doing just yet)
# - Create a directory called **Practice** by typing command **os.mkdir('Practice')**.
# - List the contents of the current directory by typing command **os.listdir()**.
# - Remove the directory **Practice** by typing command **os.rmdir('Practice')**.
# - List the contents of the current directory again.
