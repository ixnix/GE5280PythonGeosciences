# %% [markdown]
# ## Assignment 10
#
# - Answer each question in a separate cell.
# - Turn in your notebook via Canvas.
# - Before submitting, make sure your notebook has no compiling errors. Use 'Restart Kernel' to clear the computer memory and then "Run all cells".

# %% [markdown]
# ### 1. Working with Datetime
#
# - Import the **datetime** class from the **datetime** module.
# - Call the **today()** method of the **datetime** class and assign the result to a variable named **today**.
# - Print the year, month, day, hour, and minute attributes of **today**.
# - Use **pd.date_range()** to generate a **DatetimeIndex** named **dates** by setting start to **today**, frequency to 3 hours, and periods to 8.
# - Convert **dates** to a list of Timestamp objects by calling the **.to_list()** method; Assign it to **datelist**.
# - Use **list comprehension** with the **strftime()** method to format each timestamp in **datelist** as strings like:
#     '22:23 PM 07 November 2022, Sunday', ...
# - Repeat the above step, but format the timestamps as 2022-11-07T22:23:00, ...
# - Use **pd.date_range()** to generate a list of **DatetimeIndex** from '1/1/2025' to '12/31/2025' at daily frequency.

# %%
# Write your code here

# %% [markdown]
# ### 2. Working with Timedelta
#
# - Import both the **datetime** and **timedelta** classes from the **datetime** module.
# - Call the **today()** method of the **datetime** class and assign the result to a variable named **_today_**.
# - Create a new variable **olddate** to store a **datetime** object of **November 1, 2024, 12:00:00**.
# - Calculate the time difference between **today** and **olddate**; Print out the result and verify that it is a **timedelta** object.
# - Create a new variable **tdiff** to store a **timedelta** object of **3 hours**.
# - Add **tdiff** to **today**; Print out the result.

# %%
# Write your code here

# %% [markdown]
# ### 3. Resampling Time Series
# - Use **pd.read_csv()** to read **Houghton.csv** as a DataFrame **df**; Set the **DATE** column as the index; Parse the **DATE** column as DatetimeIndex (hint: use **parse_dates** and **index_col** keywords).
#
# - Print the first 5 rows of **df**.
#    - **_df_** contains hourly weather measurements at Houghton-Hancock airport for 2020, including: temperature (**T**), relative humidity (**RH**), pressure (**P**), wind speed (**SPD**), wind direction (**DIR**), weather condition code (**WEA**), visibility (**VIS**), and liquid rain amount (**RAIN**).
#
# - Resample **df** to calculate 3-hourly mean wind speed; Print out the first 5 rows.
#
# - Resample **_df_** to calculate the following daily statistics and print out the first 5 rows. Name the output **_dfDaily_**.
#    - Mean T
#    - Max SPD
#    - Total RAIN
#    - Hint: use **agg()** with **mean** for T, **max** for SPD, and **sum** for RAIN.
#
# - Repeat step 4 for a **monthly frequency**. Print the first 5 rows. Name the output **_dfMonthly_**.
#
# - Plot **daily** and **monthly mean T** on the same figure:
#    - **Daily T:** black solid line
#    - **Monthly T:** red marker line
#
# - Calculate the correlation matrix for **_dfDaily_**, using the **.corr()** method.

# %%
# Write your code here
